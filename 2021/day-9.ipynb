# %%
with open("data/day-9.txt") as file:
    lines = [list(line.strip()) for line in file.readlines()]

lines[0]
# Out:
# ['8',
#  '9',
#  '6',
#  '9',
#  '7',
#  '9',
#  '9',
#  '9',
#  '8',
#  '7',
#  '6',
#  '4',
#  '6',
#  '7',
#  '9',
#  '8',
#  '9',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '9',
#  '7',
#  '5',
#  '4',
#  '3',
#  '5',
#  '3',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '9',
#  '8',
#  '7',
#  '9',
#  '7',
#  '6',
#  '9',
#  '9',
#  '9',
#  '8',
#  '6',
#  '7',
#  '9',
#  '7',
#  '6',
#  '7',
#  '9',
#  '4',
#  '4',
#  '6',
#  '8',
#  '9',
#  '9',
#  '9',
#  '9',
#  '7',
#  '9',
#  '7',
#  '5',
#  '9',
#  '8',
#  '6',
#  '5',
#  '7',
#  '6',
#  '7',
#  '8',
#  '9',
#  '6',
#  '5',
#  '4',
#  '5',
#  '6',
#  '9',
#  '9',
#  '8',
#  '6',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9',
#  '5',
#  '2',
#  '1',
#  '2',
#  '3',
#  '8',
#  '9',
#  '9',
#  '3',
#  '2',
#  '5',
#  '4',
#  '5',
#  '6']
